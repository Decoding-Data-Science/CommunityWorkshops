# %% [markdown]
# <a href="https://colab.research.google.com/github/Decoding-Data-Science/CommunityWorkshops/blob/main/30july_of_dds_hr_chatbot_free.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DDS HR Enterprise Chatbot — GitHub Models (GPT-5)
# Free GitHub key → GPT-5 (reasoning model) + embeddings → your HR PDFs → Gradio chat. No OpenAI key, no credit card.

# %%
# !pip install -q llama_index llama-index-readers-file llama-index-llms-openai-like gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.8/51.8 kB 4.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 86.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 90.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 35.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 17.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 72.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 5.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.6/142.6 kB 10.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torch 2.11.0+cpu requires setuptools<82, but you have setuptools 83.0.0 which is incompatible.

# %% [markdown]
# ## Step 1 — Put your HR PDFs in a `data` folder
# In the Colab file browser (folder icon, left sidebar), create a folder called `data` and upload your HR PDFs into it.

# %% [markdown]
# ## Step 2 — Connect to GitHub Models
# One free key, kept in Colab Secrets. Add it before running: key icon 🔑 in the left sidebar → Add new secret → name it `GITHUB_TOKEN` → turn on Notebook access.

# %%
from google.colab import userdata

GITHUB_TOKEN = userdata.get("GITHUB_TOKEN")
GITHUB_MODELS_BASE_URL = "https://models.github.ai/inference"

# %% [markdown]
# ## Step 3 — Load the documents

# %%
from llama_index.core import SimpleDirectoryReader
from llama_index.readers.file import PDFReader

documents = SimpleDirectoryReader(
    input_dir="data",
    required_exts=[".pdf"],
    file_extractor={".pdf": PDFReader()}
).load_data()

print(len(documents))
print(documents[0].text[:500])
# Out:
# 13
# DDS Employee Handbook (Synthetic) v1
# Effective date: March 03, 2026  Dubai (GST)
# Note: This document is a synthetic, training-friendly employee handbook for demos, onboarding
# simulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified
# counsel before any real-world use.
# 1. Welcome to Decoding Data Science (DDS)
# DDS is a Dubai-based academy, consulting practice, and community focused on data science, AI, and
# applied generative AI. We operate with a glob

# %% [markdown]
# ## Step 4 — Configure GPT-5 + embeddings
# **Note:** GPT-5 is a reasoning model on GitHub Models — no `temperature` parameter. `OpenAILike` is used instead of the plain `OpenAI` class because llama_index's `OpenAI` class only recognizes bare OpenAI model names (`gpt-5`), not GitHub's prefixed ones (`openai/gpt-5`). `model_name=` (not `model=`) is used for the embedding model for the same reason.

# %%
from llama_index.core import VectorStoreIndex, Settings
from llama_index.llms.openai_like import OpenAILike
from llama_index.embeddings.openai import OpenAIEmbedding

Settings.llm = OpenAILike(
    model="openai/gpt-4o-mini",
    api_base=GITHUB_MODELS_BASE_URL,
    api_key=GITHUB_TOKEN,
    is_chat_model=True,
    context_window=128000,
    temperature=0.2,   # gpt-4o-mini isn't a reasoning model, so temperature works here
)

Settings.embed_model = OpenAIEmbedding(
    model_name="openai/text-embedding-3-small",
    api_base=GITHUB_MODELS_BASE_URL,
    api_key=GITHUB_TOKEN,
)

Settings.chunk_size = 600
Settings.chunk_overlap = 200

# %%
from llama_index.core import VectorStoreIndex, Settings
from llama_index.llms.openai_like import OpenAILike
from llama_index.embeddings.openai import OpenAIEmbedding

Settings.llm = OpenAILike(
    model="openai/gpt-5",
    api_base=GITHUB_MODELS_BASE_URL,
    api_key=GITHUB_TOKEN,
    is_chat_model=True,
    context_window=128000,
    temperature=0.2,   # gpt-4o-mini isn't a reasoning model, so temperature works here
)

Settings.embed_model = OpenAIEmbedding(
    model_name="openai/text-embedding-3-small",
    api_base=GITHUB_MODELS_BASE_URL,
    api_key=GITHUB_TOKEN,
)

Settings.chunk_size = 600
Settings.chunk_overlap = 200

# %% [markdown]
# ## Step 5 — Ayesha, the DDS HR system prompt

# %%
system_prompt = '''

You are Ayesha, the Decoding Data Science (DDS) Enterprise HR Chatbot. Your objective is to interact politely and professionally with employees, answering only HR-related questions. Use only information directly from the connected HR documents to provide your answers. Always provide an explicit citation indicating the document source for every answer. Do not offer information or suggestions beyond what is present in these documents.

If the requested information cannot be found in the connected documents, politely instruct the user to email connect@decodingdatascience.com for further assistance. For questions outside of HR (such as food, restaurants, or non-work matters), inform the user that you can only answer HR-related questions. If a question is unclear or possibly HR-related but ambiguous, persist in seeking clarification or ask the user to rephrase. Never attempt to answer non-HR, personal, or unrelated questions.

- Remain polite and professional in all interactions.
- Respond exclusively to HR-related topics (e.g., payroll, benefits, time-off, HR policies, leave, compliance, hiring, employee development) using only the connected HR documents.
- Always include an explicit citation to the relevant document(s) for every answer.
- If a question is off-topic, state that you can only address HR questions.
- If you are unsure whether the question is HR-related, politely ask for clarification or rephrasing.
- For HR-related questions where the answer is not in the connected documents, kindly direct the user to email connect@decodingdatascience.com.
- Use a friendly and formal tone.
- Always persist in seeking clarification for ambiguous or insufficiently clear questions before providing an answer or deferring.

**Output Format:**
Respond in short, clear paragraphs (2-4 sentences). Do not use markdown or code blocks. Every answer must include the citation showing which document(s) the information is sourced from.

# Examples

**Example 1**
Input: What is the process for applying for maternity leave?
Output: Thank you for your question regarding maternity leave. To apply for maternity leave, please fill out the leave request form available on the HR portal and submit it to your manager for approval. Source: Document 2, Leave Policy.

**Example 2**
Input: Where is the best place to get lunch nearby?
Output: I can only assist with HR-related questions. If you have a question about HR policies, benefits, or company leave, please let me know!

**Example 3**
Input: How can I apply for a sabbatical leave?
Output: I am sorry, but I could not find information regarding sabbatical leave in our HR documents. For further assistance, please email connect@decodingdatascience.com.

'''

# %% [markdown]
# ## Step 6 — Build the index and try a question

# %%
documents
# Out:
# [Document(id_='276007ae-c188-47fc-9e47-f6ee47533ad1', embedding=None, metadata={'page_label': '1', 'file_name': 'DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\n1. Welcome to Decoding Data Science (DDS)\nDDS is a Dubai-based academy, consulting practice, and community focused on data science, AI, and\napplied generative AI. We operate with a global mindset and a high trust culture—shipping practical\noutcomes while supporting each other.\nThis handbook explains workplace expectations, benefits, and policies. If any local law conflicts with\nthis handbook, applicable law prevails.\n2. Company Values & Ways of Working\n\x7f Build with clarity: define the user, problem, inputs/outputs, and definition of done.\n\x7f Bias for action: ship small, iterate fast, measure outcomes.\n\x7f Respect and inclusion: disagreement is allowed; disrespect is not.\n\x7f Data integrity: be precise with claims; cite sources; protect confidential information.\n\x7f Learning culture: continuous improvement is part of the job.\n3. Employment Classification (Synthetic Example)\nDDS may engage team members as:\n\x7f Full-time employees (UAE employment contract).\n\x7f Part-time employees (limited hours as per contract).\n\x7f Contractors / freelancers (service agreement).\nYour offer letter/contract defines your classification, compensation terms, notice periods, and\nbenefits.\n4. Equal Opportunity, Anti-Discrimination & Anti-Harassment\nDDS is committed to a workplace free from discrimination and harassment. We do not tolerate harassment\nbased on protected characteristics.\n\x7f Report concerns to HR or a designated People Partner.\n\x7f Reports are handled confidentially to the extent possible.\n\x7f Retaliation against anyone raising a concern in good faith is prohibited.\n\x7f Investigations may include interviews, review of communications, and documented outcomes.\n5. Code of Conduct\nAll team members are expected to:\n\x7f Act professionally with colleagues, partners, and learners.\n\x7f Avoid conflicts of interest; disclose them promptly.\n\x7f Use company resources responsibly.\n\x7f Follow lawful and ethical practices when using AI systems (no plagiarism, no misuse of data).\n\x7f Respect intellectual property and licensing obligations.\n6. Working Hours & Attendance (Hybrid/Global Teams)\n\x7f Standard office hours (Dubai): 9:00–18:00, Monday–Friday.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='96eab0cf-e45c-406a-b105-1d966fd74dbe', embedding=None, metadata={'page_label': '2', 'file_name': 'DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n\x7f Teams operating across time zones set 'core collaboration hours' (e.g., 12:00–16:00 GST) where\n  meetings may be scheduled.\n\x7f Outside core hours, work is flexible and outcome-based.\nAttendance expectations:\n\x7f Join scheduled meetings on time; inform the host if running late.\n\x7f If unexpectedly absent, notify your manager as soon as possible.\n\x7f Repeated unexplained absences may trigger a performance/disciplinary process.\n7. Breaks, Overtime & Time Off in Lieu (TOIL)\n\x7f Breaks should be taken in a way that supports health and productivity.\n\x7f For roles where overtime may occur (events, launches), managers may approve TOIL.\n\x7f Overtime/TOIL rules depend on local contract terms and applicable labor law.\n\x7f Log time in the agreed tracker when required by your team.\n8. Probation & Confirmation\nNew hires may be placed on a probation period as stated in the employment contract.\n\x7f During probation, performance expectations are set clearly with weekly check-ins.\n\x7f Confirmation occurs after successful completion of probation and required documentation.\n9. Performance Management\nDDS uses an outcomes-first approach:\n\x7f Quarterly goals (OKRs or milestone plans) aligned to the business roadmap.\n\x7f Regular 1:1 check-ins with managers.\n\x7f Feedback is specific, timely, and actionable.\nIf performance concerns arise:\n\x7f Step 1: Clarify expectations and provide support.\n\x7f Step 2: Document a performance improvement plan (PIP) with measurable milestones.\n\x7f Step 3: Review outcomes; further action may include role change or termination (per contract/law).\n10. Learning, Training & Development\nDDS invests in learning because it is core to our mission.\n\x7f Team members may receive access to internal courses, recordings, and selected external trainings.\n\x7f Sharing learnings is encouraged: short notes, demos, internal talks.\n\x7f Training time is scheduled with managers to protect delivery commitments.\n11. Confidentiality & Intellectual Property\nConfidential information includes (but is not limited to): learner data, pricing, partnerships, product\nroadmaps, internal docs, and source code.\n\x7f Do not share confidential information externally without approval.\n\x7f Work created in the course of employment may be owned by DDS as per contract terms.\n\x7f Respect third-party IP: do not copy copyrighted content into DDS assets without proper licensing.\n12. Data Protection & Privacy (Operational Expectations)\nDDS handles personal and business data responsibly.\nPage 2\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='4643fcd3-6c61-4b17-a2e4-c45f9bcee40a', embedding=None, metadata={'page_label': '3', 'file_name': 'DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n\x7f Only collect data that is necessary.\n\x7f Store data only in approved systems.\n\x7f Apply least-privilege access.\n\x7f Never export learner/employee data to personal devices or unapproved tools.\n\x7f AI tools: do not paste confidential data into public chatbots unless an approved enterprise\n  environment is in place.\nReport suspected data incidents immediately to your manager and the security/IT owner.\n13. Acceptable Use of AI Tools\nAI is part of our workflows, but must be used safely:\n\x7f Verify outputs; do not treat AI as a source of truth.\n\x7f Cite sources when producing research or educational content.\n\x7f Avoid generating deceptive content or misrepresenting AI-generated work as human work when it matters.\n\x7f Use approved model providers and enterprise settings when handling sensitive data.\n\x7f For client work, follow client contractual constraints on data/model usage.\n14. Communications, Social Media & Public Representation\nDDS has a strong public presence; how we communicate matters.\n\x7f Be respectful and factual in public channels.\n\x7f Do not announce partnerships, pricing, or internal matters without approval.\n\x7f If you speak as an individual, clarify that opinions are your own.\n\x7f For press/media requests, route to the designated spokesperson.\n15. Workplace Safety, Wellbeing & Emergency Procedures\n\x7f Follow building safety instructions in offices/event venues.\n\x7f Report hazards promptly.\n\x7f In emergencies, prioritize people safety and follow local authorities' instructions.\n\x7f DDS supports wellbeing through reasonable workloads, clear planning, and respectful collaboration.\n16. Disciplinary Process (Simplified)\nDepending on severity, DDS may use progressive steps:\n\x7f Coaching and verbal warning.\n\x7f Written warning with clear expectations.\n\x7f Final warning or performance plan.\n\x7f Termination (for severe misconduct or repeated issues).\nGross misconduct examples (non-exhaustive): harassment, theft, serious data breach, violence, fraud, or\nwillful policy violation.\n17. Grievance & Reporting Channels\nIf you have a complaint or concern:\n\x7f Step 1: Raise it with your manager (if appropriate).\n\x7f Step 2: If not resolved or not appropriate, contact HR/People Partner.\n\x7f Step 3: Escalate to leadership if needed.\nDDS aims to respond quickly, document actions taken, and protect confidentiality.\nPage 3\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='43253494-51a9-4c87-9809-b90e2f55d9e9', embedding=None, metadata={'page_label': '4', 'file_name': 'DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Employee_Handbook_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 9665, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Employee Handbook (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n18. Policy Governance & Updates\nThis handbook may be updated as DDS evolves.\n\x7f HR communicates material changes.\n\x7f The latest version lives in the internal knowledge base.\n\x7f Your contract and local labor law remain the governing documents where applicable.\nPage 4\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='0ac30a84-96f6-4b4d-97f4-ccf015c470a2', embedding=None, metadata={'page_label': '1', 'file_name': 'DDS_HR_FAQ_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_HR_FAQ_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 2933, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS HR FAQ (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\nHow do I request leave?\nSubmit a request in the leave system (or the approved tracker) with dates and a short coverage plan.\nNotify your manager and any stakeholders affected by deadlines.\nTypical approval time: 1–3 business days (may vary during peak periods).\nWhat should I do if I’m sick?\nInform your manager as soon as possible. If you will be absent for 2+ consecutive workdays, you may be\nasked to provide a medical certificate (as allowed by contract/law). Focus on recovery first.\nCan I work remotely full-time?\nIt depends on your role, performance, and operational needs. Discuss with your manager. HR may provide\nrole-based guidelines.\nWhat tools should I use for work?\nUse DDS-approved tools for email, documents, chat, project tracking, and file storage. If you’re unsure,\nask your manager or IT owner.\nHow do I report harassment or discrimination?\nYou can contact HR/People Partner directly, or raise it with your manager if appropriate.\nConfidentiality is respected, and retaliation is prohibited.\nWhere do I ask case-specific questions?\nFor personal or case-specific issues (leave exceptions, conflicts, concerns), contact HR directly. DDS\nwill handle your request discreetly.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='bc0eb07f-884c-4f44-abfd-d6cc098b3d2b', embedding=None, metadata={'page_label': '1', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 1\n Leave Policy\nDecoding Data Science (DDS) — People & Culture\nDocument ID: DDS-HR-POL-001 · Version 2.0 · Effective date: 1 July 2026 · Applies to: All DDS\nemployees (Dubai, UAE and remote)\nThis policy defines all leave entitlements at DDS, how leave accrues, how to request it, and how requests are\napproved. It replaces Leave Policy v1 (March 2026) in full. Where UAE Federal Decree-Law No. 33 of 2021\n(the UAE Labour Law) provides a greater benefit, the law prevails.\nNote: this is a synthetic, training-friendly policy created for demos, onboarding simulations, and HR-chatbot prototypes. It is not\nlegal advice.\n1. Leave Entitlements at a Glance\nLeave type\nEntitlement\nPay\nMinimum notice\nEvidence required\nAnnual leave\n22 working days per year\nFull pay\n7 calendar days (see\n§3.4)\nNone\nSick leave\n15 working days per year at\nfull pay\nFull pay (then\nper §4.4)\nSame day, within 1\nhour of start time\nMedical certificate for\n2+ consecutive days\nMaternity leave\n60 calendar days\nFull pay\n30 calendar days\nbefore expected\ndate\nMedical\ndocumentation\nPaternity leave\n5 working days, within 6\nmonths of birth\nFull pay\n30 calendar days\nwhere foreseeable\nBirth certificate\nParental leave\n(additional)\n5 working days per parent,\nwithin 6 months of birth\nFull pay\n14 calendar days\nBirth certificate\nBereavement leave\n5 working days\n(spouse/child/parent); 3\nworking days\n(sibling/grandparent)\nFull pay\nNotify as soon as\npossible\nMay be requested\nMarriage leave\n3 working days (once during\nemployment)\nFull pay\n14 calendar days\nMarriage certificate\nStudy leave\n10 working days per year (2+\nyears of service, enrolled at\nan accredited UAE institution)\nFull pay\n14 calendar days\nExam schedule /\nenrollment proof\nHajj leave\nUp to 30 calendar days (once\nduring employment)\nUnpaid\n60 calendar days\nNone\nUnpaid leave\nUp to 30 calendar days per\nyear, case-by-case\nUnpaid\n30 calendar days\nManager + HR\napproval\nPublic holidays\nPer the official UAE calendar\nFull pay\nNot applicable\nNot deducted from\nannual leave\n2. Definitions\n\x7f Leave year: 1 January to 31 December.\n\x7f Working day: Monday to Friday, excluding UAE public holidays.\n\x7f Calendar day: any day, including weekends and public holidays.\n\x7f Immediate family: spouse, child, or parent.\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='31507144-ff07-43f4-8af8-5e6ee6f67a07', embedding=None, metadata={'page_label': '2', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 2\n\x7f Leave system: the DDS HR portal where all leave is requested, approved, and tracked.\n3. Annual Leave\n3.1 Entitlement\nFull-time employees are entitled to 22 working days of paid annual leave per leave year. Part-time\nemployees receive a pro-rata entitlement based on contracted hours. Employees who join or leave mid-year\nreceive a pro-rata entitlement for that year.\n3.2 Accrual\nAnnual leave accrues at 1.83 working days per completed calendar month of service. During the probation\nperiod, leave accrues normally; accrued days may be used during probation with line-manager approval.\n3.3 Booking limits\n\x7f The maximum single block of annual leave is 15 consecutive working days. Longer blocks require\nCEO approval.\n\x7f At least 5 of the 22 days must be taken as one continuous block of 5 working days each year, to support\ngenuine rest.\n\x7f Leave may be taken in half-day units at minimum.\n3.4 Notice periods for annual leave requests\nLength of leave requested\nMinimum notice before start date\n1–2 working days\n7 calendar days\n3–9 working days\n14 calendar days\n10 or more working days\n30 calendar days\nManagers respond to leave requests within 3 business days. Employees should not book non-refundable\ntravel before approval is confirmed in the leave system.\n3.5 Peak periods\nDuring flagship delivery windows (major bootcamps, the annual conference season, and product launches),\napprovals may be restricted. HR publishes restricted weeks at the start of each quarter. Requests in restricted\nweeks require Head-of-Department approval.\n4. Carry-Over, Expiry and Encashment\n4.1 Carry-over\nA maximum of 10 unused annual-leave days may be carried into the next leave year. Carry-over is\nautomatic; no approval is needed.\n4.2 Expiry\nCarried-over days must be used by 31 March (end of Q1) of the new leave year. Any carried-over days not\nused by 31 March expire without compensation.\n4.3 Encashment\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='f3ce11bd-f9a0-42f7-9bb4-5fef0eac527d', embedding=None, metadata={'page_label': '3', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 3\nUnused annual leave is not paid out during employment. On termination of employment, accrued but unused\nannual leave for the current year is paid out at the employee's basic salary rate, in line with UAE Labour Law.\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='57b837a3-ab48-4812-9e94-363059e86b31', embedding=None, metadata={'page_label': '4', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 4\n5. Sick Leave\n5.1 Entitlement\nEmployees receive 15 working days of fully paid sick leave per leave year, available after completion of\nthe probation period.\n5.2 Notification\n\x7f Notify your line manager within 1 hour of your normal start time on the first day of absence (message\nor call).\n\x7f Log the absence in the leave system on the day of return, or earlier if able.\n5.3 Medical certificates\nA medical certificate from a licensed practitioner is required for any absence of 2 or more consecutive\nworking days, and may be requested for shorter or repeated absences where a pattern suggests misuse.\n5.4 Extended illness\nIf an illness continues beyond the 15 fully paid days, additional sick leave follows the UAE Labour Law\nstructure within the same leave year: up to 30 further calendar days at half pay, then up to 45 further\ncalendar days unpaid, subject to medical documentation. HR manages extended-illness cases confidentially\nwith the employee.\n5.5 Partial working\nIf an employee is unwell but able to work reduced hours, this may be agreed with the line manager. Health\nalways takes priority; nobody is expected to work while genuinely unwell.\n6. Public Holidays\n\x7f DDS observes the official UAE public-holiday calendar for Dubai-based employees. HR publishes the\ncalendar each January.\n\x7f Public holidays are paid and are not deducted from the annual-leave balance.\n\x7f If a public holiday falls within an approved period of annual leave, that day is not counted as an\nannual-leave day.\n\x7f Employees contracted outside the UAE observe the public holidays of their contract location.\n\x7f Where business-critical operations (live events, launches) require work on a public holiday, the employee\nreceives a substitute day off in lieu, to be taken within 60 days.\n7. Maternity, Paternity and Parental Leave\n7.1 Maternity leave\n\x7f 60 calendar days at full pay. This exceeds the UAE statutory minimum as an enhanced DDS benefit.\n\x7f Notify HR at least 30 calendar days before the expected date of leave, with medical documentation.\n\x7f Leave may begin up to 30 days before the expected delivery date.\n\x7f An additional period of up to 45 calendar days unpaid may be taken for medical reasons related to the\npregnancy or delivery, with a medical certificate.\n7.2 Nursing breaks\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='02aab1dc-1c38-4e24-92fa-c5e459362d0e', embedding=None, metadata={'page_label': '5', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 5\nFor 6 months following return from maternity leave, the employee is entitled to one paid nursing break of 1\nhour per day, scheduled flexibly with the line manager.\n7.3 Paternity leave\nFathers receive 5 working days at full pay, to be taken within 6 months of the child's birth, consecutively or\nsplit. Provide notice 30 calendar days ahead where foreseeable.\n7.4 Parental leave (additional)\nIn addition to maternity/paternity leave, each parent may take 5 working days of paid parental leave within\n6 months of the birth, in line with UAE Labour Law.\n7.5 Adoption\nEmployees adopting a child under the age of 5 receive the same entitlements as in §7.1–7.4, measured from\nthe date of placement.\n7.6 Return to work\nManagers must agree a written transition plan before leave begins and a re-onboarding plan for the return.\nReturning parents come back to the same role or an equivalent role on the same terms.\n8. Other Leave Types\n8.1 Bereavement (compassionate) leave\n5 working days at full pay for the death of a spouse, child, or parent; 3 working days at full pay for the\ndeath of a sibling, grandparent, or grandchild. Notify your manager as soon as possible; documentation may\nbe requested. Additional unpaid leave may be approved case-by-case.\n8.2 Marriage leave\n3 working days at full pay, once during employment, taken within 30 days of the marriage. Provide 14\ncalendar days' notice and a marriage certificate.\n8.3 Study and exam leave\nEmployees with 2 or more years of service who are enrolled at an accredited UAE educational institution\nreceive 10 working days of paid study leave per year for examinations, per UAE Labour Law. Provide the\nexam schedule 14 calendar days ahead.\n8.4 Hajj leave\nMuslim employees may take up to 30 calendar days of unpaid leave once during their employment to\nperform Hajj. Request 60 calendar days in advance so coverage can be planned.\n8.5 Unpaid leave\n\x7f Up to 30 calendar days per leave year, approved case-by-case by the line manager and HR.\n\x7f Annual leave must be exhausted first unless HR agrees otherwise.\n\x7f Unpaid leave may affect payroll, benefits accrual, and visa arrangements; HR will confirm the impact in\nwriting before approval.\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='12cb078a-33a6-4f3f-8f0a-5f59774a9992', embedding=None, metadata={'page_label': '6', 'file_name': 'DDS_Leave_Policy_v2.pdf', 'file_path': '/content/data/DDS_Leave_Policy_v2.pdf', 'file_type': 'application/pdf', 'file_size': 16573, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text="DECODING DATA SCIENCE  |  PEOPLE & CULTURE\nDDS-HR-POL-001  ·  Leave Policy  ·  v2.0\nInternal — Synthetic demo document for AI training purposes. Not legal advice.\nPage 6\n9. Religious Observance and Ramadan Working Hours\n\x7f During Ramadan, daily working hours are reduced by 2 hours for all employees, per UAE regulation.\n\x7f Teams schedule meetings considerately around fasting and prayer times.\n\x7f Additional flexibility (shifted hours, remote days) can be agreed with the line manager where the role\nallows.\n10. How to Request Leave (Workflow)\nStep\nAction\nOwner\nTiming\n1\nSubmit the request in the leave system with dates, leave\ntype, and a short coverage plan (deliverables, who\ncovers, key deadlines).\nEmployee\nPer the notice table in\n§3.4\n2\nReview and approve/decline with a reason.\nLine manager\nWithin 3 business days\n3\nCompliance check for balance, carry-over expiry, and\nrestricted weeks.\nHR\nAutomatic in the leave\nsystem\n4\nNotify affected stakeholders and hand over client-facing\ncommitments.\nEmployee\nBefore leave starts\n5\nEmergency leave: notify your manager immediately by\nany channel, then submit the request retroactively.\nEmployee\nWithin 48 hours\nApproved leave appears in the shared team calendar. Cancelling approved leave restores the days to the\nemployee's balance automatically.\n11. Misuse and Compliance\n\x7f Misrepresenting sickness, falsifying certificates, or working a second job while on sick leave are treated\nas misconduct under the DDS Disciplinary Policy.\n\x7f DDS may request documentation where reasonable and lawful.\n\x7f Managers may not pressure employees to cancel or shorten approved leave except in genuine business\nemergencies, and any such case must be reported to HR.\n12. Governance\n\x7f Policy owner: Head of People & Culture, DDS.\n\x7f Review cycle: annually, each June, or earlier if UAE labour regulations change.\n\x7f Precedence: where an employment contract or UAE Labour Law grants a greater benefit, that provision\nprevails over this policy.\n\x7f Questions: contact People & Culture via the HR portal, or ask DecoBot, the DDS HR assistant.\nVersion history — v1.0 (March 2026): initial synthetic policy. v2.0 (July 2026): full rewrite with fixed entitlements, notice tables,\ncarry-over and expiry rules, extended parental provisions, and workflow SLAs.\n", path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='fa559ab8-3faa-4869-9095-8b75cb7482b7', embedding=None, metadata={'page_label': '1', 'file_name': 'DDS_Remote_Work_Policy_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Remote_Work_Policy_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 4707, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Remote Work Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\nNote: This document is a synthetic, training-friendly employee handbook for demos, onboarding\nsimulations, and HR-policy chatbot prototypes. It is not legal advice and must be reviewed by qualified\ncounsel before any real-world use.\n1. Remote Work Philosophy\nDDS supports remote and hybrid work because our team and learners are global. Remote work is a privilege\ntied to trust, outcomes, and security.\nRemote success requires:\n\x7f Clear goals and ownership.\n\x7f High-quality written communication.\n\x7f Reliable availability during core collaboration hours.\n2. Eligibility & Approval\nRemote work depends on role suitability, performance, and operational needs.\n\x7f Approval is granted by the line manager.\n\x7f HR may define role-based constraints (e.g., event roles require onsite presence).\n\x7f DDS may revoke remote status if outcomes or security requirements are not met.\n3. Working Hours & Availability\n\x7f Teams define core hours where everyone is expected to be reachable.\n\x7f Outside core hours, work is flexible as long as deliverables are met.\n\x7f Keep calendars accurate; update status (busy/OOO) and response expectations.\n4. Home Office Setup (Minimum Standard)\n\x7f Stable internet connection and a quiet workspace.\n\x7f Headset for calls; webcam as required for meetings.\n\x7f Ability to protect confidential information (no shoulder-surfing, lock screen).\n\x7f Use approved storage and collaboration tools.\n5. Security & Data Handling\n\x7f Use company-approved devices when provided.\n\x7f Enable strong authentication (MFA) on all work accounts.\n\x7f Keep devices updated with security patches.\n\x7f Do not store DDS data on personal cloud drives or unapproved services.\n\x7f Report lost devices or suspected compromise immediately.\nAI tools:\n\x7f Do not paste confidential documents into public AI tools.\n\x7f Use approved enterprise environments for sensitive data when available.\n6. Meetings, Documentation & Asynchronous Work\nDDS prefers async-first documentation:\n\x7f Write decisions and action items in shared docs.\n\x7f Record key meetings when appropriate (with consent).\n\x7f Use clear templates for project updates (status, risks, next steps).\n\x7f Reduce unnecessary meetings; default to written updates when possible.\nPage 1\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'),
#  Document(id_='61d2de7a-97a2-4850-a77c-3f5628af699b', embedding=None, metadata={'page_label': '2', 'file_name': 'DDS_Remote_Work_Policy_Synthetic_v1.pdf', 'file_path': '/content/data/DDS_Remote_Work_Policy_Synthetic_v1.pdf', 'file_type': 'application/pdf', 'file_size': 4707, 'creation_date': '2026-07-30', 'last_modified_date': '2026-07-30'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='DDS Remote Work Policy (Synthetic) v1\nEffective date: March 03, 2026 \x7f Dubai (GST)\n7. Travel, Working From Abroad (Example Rules)\n\x7f Working from outside your usual country may require manager approval.\n\x7f Consider visa, tax, and data access restrictions.\n\x7f Maintain secure connectivity; use VPN if required.\n\x7f Time zone shifts must not disrupt critical commitments.\n8. Equipment & Expenses (Example Policy)\n\x7f If DDS provides equipment, it must be used for work and returned upon exit.\n\x7f Expense reimbursement (internet/tools) depends on your contract and role.\n\x7f All expenses require receipts and prior approval where applicable.\nPage 2\nDecoding Data Science (DDS) — Internal (Synthetic Demo)\n', path=None, url=None, mimetype=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}')]

# %%
index = VectorStoreIndex.from_documents(documents=documents)
query_engine = index.as_query_engine(system_prompt=system_prompt)

response = query_engine.query("What are DDS standard office hours in Dubai?")
print(response)
# Out:
# ---------------------------------------------------------------------------
# BadRequestError                           Traceback (most recent call last)
# /tmp/ipykernel_2822/2201898824.py in <cell line: 0>()
#       2 query_engine = index.as_query_engine(system_prompt=system_prompt)
#       3
# ----> 4 response = query_engine.query("What are DDS standard office hours in Dubai?")
#       5 print(response)
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
#      42             if isinstance(str_or_query_bundle, str):
#      43                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ---> 44             query_result = self._query(str_or_query_bundle)
#      45         dispatcher.event(
#      46             QueryEndEvent(query=str_or_query_bundle, response=query_result)
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/query_engine/retriever_query_engine.py in _query(self, query_bundle)
#     207         ) as query_event:
#     208             nodes = self.retrieve(query_bundle)
# --> 209             response = self._response_synthesizer.synthesize(
#     210                 query=query_bundle,
#     211                 nodes=nodes,
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/base.py in synthesize(self, query, nodes, additional_source_nodes, **response_kwargs)
#     286                 )
#     287             else:
# --> 288                 response_str = self.get_response(
#     289                     query_str=query.query_str,
#     290                     text_chunks=[
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/compact_and_refine.py in get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#      41         # use prompt helper to fix compact text_chunks under the prompt limitation
#      42         new_texts = self._make_compact_text_chunks(query_str, text_chunks)
# ---> 43         return super().get_response(
#      44             query_str=query_str,
#      45             text_chunks=new_texts,
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/refine.py in get_response(self, query_str, text_chunks, prev_response, **response_kwargs)
#     590     ) -> RESPONSE_TEXT_TYPE:
#     591         """Give response over chunks."""
# --> 592         return self._run_refine_loop(
#     593             query_str=query_str,
#     594             chunks=text_chunks,
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/refine.py in _run_refine_loop(self, query_str, chunks, qa_template, refine_template, make_qa_prompt_kwargs, make_refine_prompt_kwargs, start_event, end_event, prev_response, **response_kwargs)
#     480
#     481             program = self._program_factory(prompt_template)
# --> 482             if resp := self._update_response(program, prompt_kwargs, response_kwargs):
#     483                 response = resp
#     484
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/refine.py in _update_response(self, program, program_kwargs, response_kwargs)
#     334                 structured_response = cast(
#     335                     StructuredRefineResponse,
# --> 336                     program(
#     337                         **program_kwargs,
#     338                         **response_kwargs,
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/response_synthesizers/refine.py in __call__(self, *args, **kwds)
#     107                 answer = answer.model_dump_json()
#     108         else:
# --> 109             answer = self._llm.predict(
#     110                 self._prompt,
#     111                 **kwds,
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/llms/llm.py in predict(self, prompt, **prompt_args)
#     635         if self.metadata.is_chat_model:
#     636             messages = self._get_messages(prompt, **prompt_args)
# --> 637             chat_response = self.chat(messages)
#     638             output = chat_response.message.content or ""
#     639         else:
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/llms/openai_like/base.py in chat(self, messages, **kwargs)
#     184             return completion_response_to_chat_response(completion_response)
#     185
# --> 186         return super().chat(messages, **kwargs)
#     187
#     188     def stream_chat(
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/llms/callbacks.py in wrapped_llm_chat(_self, messages, **kwargs)
#     177
#     178                 try:
# --> 179                     f_return_val = f(_self, messages, **kwargs)
#     180                 except BaseException as e:
#     181                     callback_manager.on_event_end(
#
# /usr/local/lib/python3.12/dist-packages/llama_index/llms/openai/base.py in chat(self, messages, **kwargs)
#     403         else:
#     404             chat_fn = completion_to_chat_decorator(self._complete)
# --> 405         return chat_fn(messages, **kwargs)
#     406
#     407     @llm_chat_callback()
#
# /usr/local/lib/python3.12/dist-packages/llama_index/llms/openai/base.py in wrapper(self, *args, **kwargs)
#     114             max_seconds=20,
#     115         )
# --> 116         return retry(f)(self, *args, **kwargs)
#     117
#     118     return wrapper
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in wrapped_f(*args, **kw)
#     329             copy = self.copy()
#     330             wrapped_f.statistics = copy.statistics  # type: ignore[attr-defined]
# --> 331             return copy(f, *args, **kw)
#     332
#     333         def retry_with(*args: t.Any, **kwargs: t.Any) -> WrappedFn:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     468         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     369         result = None
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#     373
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in <lambda>(rs)
#     391     def _post_retry_check_actions(self, retry_state: "RetryCallState") -> None:
#     392         if not (self.iter_state.is_explicit_retry or self.iter_state.retry_run_result):
# --> 393             self._add_action_func(lambda rs: rs.outcome.result())
#     394             return
#     395
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     471             if isinstance(do, DoAttempt):
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#     475                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/llama_index/llms/openai/base.py in _chat(self, messages, **kwargs)
#     499
#     500         if self.reuse_client:
# --> 501             response = client.chat.completions.create(
#     502                 messages=message_dicts,
#     503                 stream=False,
#
# /usr/local/lib/python3.12/dist-packages/openai/_utils/_utils.py in wrapper(*args, **kwargs)
#     296                         msg = f"Missing required argument: {quote(missing[0])}"
#     297                 raise TypeError(msg)
# --> 298             return func(*args, **kwargs)
#     299
#     300         return wrapper  # type: ignore
#
# /usr/local/lib/python3.12/dist-packages/openai/resources/chat/completions/completions.py in create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, moderation, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, prompt_cache_options, prompt_cache_retention, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1279     ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1280         validate_response_format(response_format)
# -> 1281         return self._post(
#    1282             "/chat/completions",
#    1283             body=maybe_transform(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in post(self, path, cast_to, body, content, options, files, stream, stream_cls)
#    1330             method="post", url=path, json_data=body, content=content, files=to_httpx_files(files), **options
#    1331         )
# -> 1332         return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#    1333
#    1334     def patch(
#
# /usr/local/lib/python3.12/dist-packages/openai/_base_client.py in request(self, cast_to, options, stream, stream_cls)
#    1103
#    1104                 log.debug("Re-raising status error")
# -> 1105                 raise self._make_status_error_from_response(err.response) from None
#    1106
#    1107             break
#
# BadRequestError: Error code: 400 - {'error': {'code': 'unavailable_model', 'message': 'Unavailable model: gpt-5', 'details': 'Unavailable model: gpt-5'}}

# %% [markdown]
# ## Step 7 — Gradio interface

# %%
import gradio as gr

def query_document(query):
    response = query_engine.query(query)
    return str(response)

interface = gr.Interface(
    fn=query_document,
    inputs=gr.Textbox(label="Enter your query", placeholder="Type your question here..."),
    outputs=gr.Textbox(label="Response"),
    title="DDS Enterprise HR Chatbot — Ayesha (GPT-5)",
    description="Ask questions about the HR documents loaded into the system. Powered by GitHub Models — free, one key, no credit card."
)

if __name__ == "__main__":
    interface.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://723bcc420626ce530d.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://723bcc420626ce530d.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
